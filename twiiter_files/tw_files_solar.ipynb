# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import codecs
import glob

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
import matplotlib as mpl

#import
from WC import WordcloudPlot, Teste

# %%
myfile = "file1.csv"

#doc = codecs.open(myfile,'rU','UTF-16')
df = pd.read_csv(myfile ,sep=',')

#print(set(df.keys()).difference(columns))
df=df.where((pd.notnull(df)), None)

# %%
df.head()
# Out:
#                     id        date      time  timezone             user_id  \
# 0  1007278454759403521  2018-06-14  12:07:52        -3           196291217
# 1  1007278419527262209  2018-06-14  12:07:44        -3          3180719313
# 2  1007278057353371649  2018-06-14  12:06:17        -3           196291217
# 3  1007278054090166283  2018-06-14  12:06:17        -3  908366908151517185
# 4  1007277885776957440  2018-06-14  12:05:36        -3          3417693515
#
#           username                                              tweet  \
# 0  Shaan_Mukherjee  #SolarEdge introduces larger-capacity three-ph...
# 1     PV_Physicist  The speaker list for #HOPV19 seems awfully dev...
# 2  Shaan_Mukherjee  #JASolar Establishes New #Subsidiary in #South...
# 3   ClimateSamurai  #JASolar Establishes New #Subsidiary in #South...
# 4          bjpimen  $AAGC keep on going CE will come off next Penn...
#
#    replies  retweets  likes location  \
# 0        0         0      0     None
# 1        0         0      0     None
# 2        0         0      0     None
# 3        0         0      0     None
# 4        0         0      0     None
#
#                                             hashtags  \
# 0  #SolarEdge,#inverters,#Intersolar,#Solar,#Sola...
# 1  #HOPV19,#WomenInSTEM,#WomenInScience,#SolarCel...
# 2  #JASolar,#Subsidiary,#SouthKorea,#Solar,#Solar...
# 3  #JASolar,#Subsidiary,#SouthKorea,#Solar,#Solar...
# 4  #AAGCCopperWeek,#stocks,#OTCover,#SolarEnergy,...
#
#                                                 link retweet user_rt  \
# 0  https://twitter.com/Shaan_Mukherjee/status/100...    None    None
# 1  https://twitter.com/PV_Physicist/status/100727...    None    None
# 2  https://twitter.com/Shaan_Mukherjee/status/100...    None    None
# 3  https://twitter.com/ClimateSamurai/status/1007...    None    None
# 4  https://twitter.com/bjpimen/status/10072778857...    None    None
#
#                  mentions
# 0                    None
# 1  nanoGe_Conf,KamatlabND
# 2                    None
# 3         JASolarOfficial
# 4                    None
