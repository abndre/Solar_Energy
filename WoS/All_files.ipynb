# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import codecs
import glob

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
import matplotlib as mpl

#import
from WC import WordcloudPlot, Teste, WordcloudPlotLIST

# %%
columns =  ['PT', 'AU', 'BA', 'BE', 'GP', 'AF', 'BF', 'CA', 'TI', 'SO', 'SE', 'BS',
       'LA', 'DT', 'CT', 'CY', 'CL', 'SP', 'HO', 'DE', 'ID', 'AB', 'C1', 'RP',
       'EM', 'RI', 'OI', 'FU', 'FX', 'CR', 'NR', 'TC', 'Z9', 'U1', 'U2', 'PU',
       'PI', 'PA', 'SN', 'EI', 'BN', 'J9', 'JI', 'PD', 'PY', 'VL', 'IS', 'PN',
       'SU', 'SI', 'MA', 'BP', 'EP', 'AR', 'DI', 'D2', 'EA', 'EY', 'PG', 'WC',
       'SC', 'GA', 'UT', 'PM', 'OA', 'HC', 'HP', 'DA']

# %%
path =r'all/' # use your path
allFiles = glob.glob(path + "/*.txt")
#doc = codecs.open(myfile,'rU','UTF-16')

frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    print(file_)
    doc = codecs.open(file_,'rU','UTF-16')
    df = pd.read_csv(doc,usecols=columns, sep='\t',parse_dates=True)
    df=df.where((pd.notnull(df)), None)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# all/savedrecs.txt
# all/savedrecs (1).txt
# all/savedrecs (3).txt
# all/savedrecs (2).txt

# %%
frame.shape
# Out:
# (2000, 68)

# %%
from IPython.display import display
pd.options.display.max_columns = None
#pd.options.display.max_rows = 999

# %%
frame.tail()
# Out:
#     PT                                                 AU    BA    BE    GP  \
# 495  J  Liao, HC; Ho, CC; Chang, CY; Jao, MH; Darling,...  None  None  None
# 496  J                          Ismail, AA; Bahnemann, DW  None  None  None
# 497  J  Wang, H; Bai, YS; Zhang, H; Zhang, ZH; Li, JH;...  None  None  None
# 498  J                                         Nocera, DG  None  None  None
# 499  J             Murray-Clay, RA; Chiang, EI; Murray, N  None  None  None
#
#                                                     AF    BF    CA  \
# 495  Liao, Hsueh-Chung; Ho, Chun-Chih; Chang, Chun-...  None  None
# 496              Ismail, Adel A.; Bahnemann, Detlef W.  None  None
# 497  Wang, Hua; Bai, Yusong; Zhang, Hao; Zhang, Zho...  None  None
# 498                                  Nocera, Daniel G.  None  None
# 499  Murray-Clay, Ruth A.; Chiang, Eugene I.; Murra...  None  None
#
#                                                     TI  \
# 495  Additives for morphology control in high-effic...
# 496  Mesoporous titania photocatalysts: preparation...
# 497  CdS Quantum Dots-Sensitized TiO2 Nanorod Array...
# 498             Chemistry of Personalized Solar Energy
# 499               ATMOSPHERIC ESCAPE FROM HOT JUPITERS
#
#                                   SO    SE    BS       LA       DT    CT  \
# 495                  MATERIALS TODAY  None  None  English   Review  None
# 496   JOURNAL OF MATERIALS CHEMISTRY  None  None  English  Article  None
# 497  JOURNAL OF PHYSICAL CHEMISTRY C  None  None  English  Article  None
# 498              INORGANIC CHEMISTRY  None  None  English   Review  None
# 499            ASTROPHYSICAL JOURNAL  None  None  English  Article  None
#
#        CY    CL    SP    HO  \
# 495  None  None  None  None
# 496  None  None  None  None
# 497  None  None  None  None
# 498  None  None  None  None
# 499  None  None  None  None
#
#                                                     DE  \
# 495                                               None
# 496                                               None
# 497                                               None
# 498                                               None
# 499  hydrodynamics; planetary systems; stars: indiv...
#
#                                                     ID  \
# 495  OPEN-CIRCUIT VOLTAGE; POWER CONVERSION EFFICIE...
# 496  VISIBLE-LIGHT PHOTOCATALYSIS; NITROGEN-DOPED T...
# 497  SOLAR-CELLS; NANOTUBE ARRAYS; HYDROGEN GENERAT...
# 498  COUPLED ELECTRON-TRANSFER; 2-ELECTRON MIXED-VA...
# 499  EXTRASOLAR PLANET HD209458B; CLASSICAL T-TAURI...
#
#                                                     AB  \
# 495  Bulk heterojunction (BHJ) photovoltaics repres...
# 496  Titanium dioxide is a very important semicondu...
# 497  An oriented single-crystalline TiO2 nanorod or...
# 498  Personalized energy (PE) is a transformative i...
# 499  Photoionization heating from ultraviolet (UV) ...
#
#                                                     C1  \
# 495  [Liao, Hsueh-Chung; Ho, Chun-Chih; Chang, Chun...
# 496  [Ismail, Adel A.] CMRDI, Adv Mat Dept, Cairo 1...
# 497  [Zhang, Hao; Li, Jinghong] Tsinghua Univ, Dept...
# 498            MIT, Dept Chem, Cambridge, MA 02139 USA
# 499  [Murray-Clay, Ruth A.; Chiang, Eugene I.] Univ...
#
#                                                     RP  \
# 495  Darling, SB (reprint author), Argonne Natl Lab...
# 496  Ismail, AA (reprint author), CMRDI, Adv Mat De...
# 497  Li, JH (reprint author), Tsinghua Univ, Dept C...
# 498  Nocera, DG (reprint author), MIT, Dept Chem, 6...
# 499  Murray-Clay, RA (reprint author), Univ Calif B...
#
#                                                 EM  \
# 495               darling@anl.gov; suwf@ntu.edu.tw
# 496                           aismail@cmrdi.sci.eg
# 497  jhli@mail.tsinghua.edu.cn; guolin@buaa.edu.cn
# 498                                 nocera@mit.edu
# 499                   rmurray-clay@cfa.harvard.edu
#
#                                                     RI  \
# 495                           Su, Wei-Fang/C-2646-2009
# 496                      Bahnemann, Detlef/G-3375-2012
# 497  Guo, Lin/A-3564-2011; Wang, Hua/J-9550-2016; L...
# 498                                               None
# 499                                               None
#
#                                                     OI  \
# 495                   Su, Wei-Fang/0000-0002-3375-4664
# 496                                               None
# 497  Wang, Hua/0000-0002-3444-5062; Li, Jinghong/00...
# 498                                               None
# 499                                               None
#
#                                                     FU  \
# 495  National Science of Council of Taiwan [101-311...
# 496                                               None
# 497  National Basic Research Program of China [2010...
# 498                          NSF; NIH; AFOSR; ARO; DOE
# 499  Berkeley Atmospheric Sciences Center Fellowshi...
#
#                                                     FX  \
# 495  Financial support obtained from the National S...
# 496                                               None
# 497  This work was supported by the National Basic ...
# 498  D.G.N. is indebted to the many students and co...
# 499  This work was supported by a Berkeley Atmosphe...
#
#                                                     CR   NR   TC   Z9  U1  \
# 495  Aich BR, 2012, ORG ELECTRON, V13, P1736, DOI 1...  103  235  235  14
# 496  Alberius PCA, 2002, CHEM MATER, V14, P3284, DO...  154  235  237  21
# 497  Banerjee S, 2008, CHEM MATER, V20, P6784, DOI ...   31  235  245  24
# 498  Amouyal E., 1997, HOMOGENEOUS PHOTOCAT, P263; ...  178  235  236   6
# 499  Banaszkiewicz M, 1998, ASTRON ASTROPHYS, V337,...   62  235  237   1
#
#       U2                   PU          PI  \
# 495  194     ELSEVIER SCI LTD      OXFORD
# 496  233  ROYAL SOC CHEMISTRY   CAMBRIDGE
# 497  280    AMER CHEMICAL SOC  WASHINGTON
# 498  111    AMER CHEMICAL SOC  WASHINGTON
# 499   19   IOP PUBLISHING LTD     BRISTOL
#
#                                                     PA         SN         EI  \
# 495  THE BOULEVARD, LANGFORD LANE, KIDLINGTON, OXFO...  1369-7021  1873-4103
# 496  THOMAS GRAHAM HOUSE, SCIENCE PARK, MILTON RD, ...  0959-9428  1364-5501
# 497         1155 16TH ST, NW, WASHINGTON, DC 20036 USA  1932-7447       None
# 498         1155 16TH ST, NW, WASHINGTON, DC 20036 USA  0020-1669  1520-510X
# 499  DIRAC HOUSE, TEMPLE BACK, BRISTOL BS1 6BE, ENG...  0004-637X       None
#
#        BN             J9                JI     PD    PY   VL  IS    PN    SU  \
# 495  None    MATER TODAY      Mater. Today    SEP  2013   16   9  None  None
# 496  None   J MATER CHEM   J. Mater. Chem.   None  2011   21  32  None  None
# 497  None  J PHYS CHEM C  J. Phys. Chem. C  OCT 7  2010  114  39  None  None
# 498  None     INORG CHEM      Inorg. Chem.  NOV 2  2009   48  21  None  None
# 499  None    ASTROPHYS J     Astrophys. J.  MAR 1  2009  693   1  None  None
#
#        SI    MA     BP     EP    AR                            DI    D2    EA  \
# 495  None  None    326    336  None  10.1016/j.mattod.2013.08.013  None  None
# 496  None  None  11686  11707  None            10.1039/c1jm10407a  None  None
# 497  None  None  16451  16455  None             10.1021/jp104208z  None  None
# 498  None  None  10001  10017  None             10.1021/ic901328v  None  None
# 499  None  None     23     42  None    10.1088/0004-637X/693/1/23  None  None
#
#        EY  PG                                                 WC  \
# 495  None  11               Materials Science, Multidisciplinary
# 496  None  22  Chemistry, Physical; Materials Science, Multid...
# 497  None   5  Chemistry, Physical; Nanoscience & Nanotechnol...
# 498  None  17                     Chemistry, Inorganic & Nuclear
# 499  None  20                           Astronomy & Astrophysics
#
#                                                     SC     GA  \
# 495                                  Materials Science  252KB
# 496                       Chemistry; Materials Science  802IY
# 497  Chemistry; Science & Technology - Other Topics...  654ZJ
# 498                                          Chemistry  509BT
# 499                           Astronomy & Astrophysics  414ZE
#
#                       UT           PM              OA    HC    HP          DA
# 495  WOS:000327002500017         None            gold     Y     N  2018-05-11
# 496  WOS:000293504500002         None            None     Y     N  2018-05-11
# 497  WOS:000282209800051         None            None     Y     N  2018-05-11
# 498  WOS:000270987400015  1.97751e+07  green_accepted     Y     N  2018-05-11
# 499  WOS:000263903300003         None            gold  None  None  2018-05-11

# %%
WordcloudPlot(frame,'AB') #abstract

# %%
WordcloudPlot(frame,'TI')#Title

# %%
WordcloudPlot(frame,'ID')

# %%
myfile = "all/savedrecs.txt"

doc = codecs.open(myfile,'rU','UTF-16')
df = pd.read_csv(doc,usecols=columns, sep='\t')

#print(set(df.keys()).difference(columns))
df=df.where((pd.notnull(df)), None)

# %%
WordcloudPlot(df,'ID')

# %%
def trigramas(words):
 
    trigrams = []
 
    for i in range(0, len(words)):
            try:
                trigrama_obs = words[i] + ' ' + words[i+1] + ' ' + words[i+2]
                trigrams.append(trigrama_obs)
            except:
                pass
    return trigrams

# %%
triga = frame['AB']
words3=[]
for i in triga:
    if not i == None:
        words3 = words3 + trigramas(i)

# %%
words3 = set(words3)

# %%
len(words3)
# Out:
# 25345

# %%
words3 = list(words3)

# %%
words3[0]
# Out:
# 'e y n'

# %%
WordcloudPlotLIST(words3)
